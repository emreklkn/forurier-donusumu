# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from keras import models,layers
from emnist import list_datasets,extract_test_samples,extract_training_samples
from keras.models import Sequential, Model
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from keras.utils import to_categorical

list_datasets()

train_images, train_labels = extract_training_samples('balanced')
test_images, test_labels = extract_test_samples('balanced')

# %%
# Verileri yeniden şekillendirme
train_images = train_images.squeeze()
train_images = train_images.astype('float32')

test_images = test_images.squeeze()
test_images = test_images.astype('float32')

num_classes=47

# Etiketleri kategorik hale getirme
train_labels = to_categorical(train_labels, num_classes)
test_labels = to_categorical(test_labels, num_classes)

# %%
# Fourier transformu uygulayan ve özellik çıkarımı yapan fonksiyon
def extract_features(images, parameter):
    features = []
    for img in images:
        # Fourier transformunu uygulayın
        f_transform = np.fft.fft2(img)
        f_transform_shifted = np.fft.fftshift(f_transform)
        
        # Belirli bir frekans bandını çıkarmak için bir maske oluşturun 
        rows, cols = img.shape
        crow, ccol = rows // 2 , cols // 2
        mask = np.zeros((rows, cols), np.uint8)
        size_row = round(crow*parameter)
        size_col = round(ccol*parameter)
        mask[crow - size_row:crow + size_row, ccol - size_col:ccol + size_col] = 1
        
        # Maskeyi uygulayın
        f_transform_shifted_filtered = f_transform_shifted * mask
        
        # Özellik vektörüne dönüştürün (vektöre çevirip normalize edin)
        feature_vector = f_transform_shifted_filtered[crow - size_row:crow + size_row, ccol - size_col:ccol + size_col]
        
        # Magnitüd büyüklük hesaplayın
        feature_vector = np.log(np.abs(feature_vector) + 1).flatten()

        features.append(feature_vector)
        

    return features

# %%
img = train_images[38574]

# Fourier transformunu uygulayın
f_transform = np.fft.fft2(img)
f_transform_shifted = np.fft.fftshift(f_transform)

# Fourier transformunun magnitüd spektrumunu kontrol edin
magnitude_spectrum = np.log(np.abs(f_transform_shifted) + 1)
        
plt.imshow(magnitude_spectrum, cmap='gray')
plt.title('Fourier Transform Magnitude Spectrum')
plt.axis('off')
plt.show()

# %%
# Belirli bir frekans bandını çıkarmak için bir maske oluşturun (örneğin, halka maske)
rows, cols = img.shape
crow, ccol = rows // 2 , cols // 2
mask = np.zeros((rows, cols), np.uint8)
parameter = 0.4
size_row = round(crow*parameter)
size_col = round(ccol*parameter)
mask[crow - size_row:crow + size_row, ccol - size_col:ccol + size_col] = 1
        
# Maskeyi uygulayın
f_transform_shifted_filtered = f_transform_shifted * mask

# Maskelenmiş magnitüd spektrumunu kontrol edin
magnitude_spectrum_filtered = np.log(np.abs(f_transform_shifted_filtered) + 1)
        
plt.imshow(magnitude_spectrum_filtered, cmap='gray')
plt.title('Masked Magnitude Spectrum')
plt.axis('off')
plt.show()

# %%
# Özellik vektörüne dönüştürün
f_transform_shifted_filtered_masked = f_transform_shifted_filtered[crow - size_row:crow + size_row, ccol - size_col:ccol + size_col]
feature_vector = np.log(np.abs(f_transform_shifted_filtered_masked) + 1).flatten()
plt.plot(feature_vector)  # özellik vektörünü göster
plt.title('Özellik Vektörü')
plt.axis('off')
plt.show()

# %%
# Çıkarılan özellikleri ve ilk birkaç resmi görselleştirin
plt.figure(figsize=(12, 8))
plt.subplot(1, 2, 1)
plt.imshow(img, cmap='gray')
plt.title('Orijinal Resim')
plt.axis('off')
       
# Ters Fourier transformunu uygulayın
f_transform_shifted = np.fft.ifftshift(f_transform_shifted_filtered)
reconstructed_img = np.fft.ifft2(f_transform_shifted)
reconstructed_img = np.abs(reconstructed_img)
    
plt.subplot(1, 2, 2)
plt.imshow(reconstructed_img, cmap='gray')  # İlk 100 özellik bileşenini göster
plt.title('Yeniden Oluşturulmuş Resim')
plt.axis('off')

plt.show()

# %%
features_train = extract_features(train_images, 0.4)
features_test = extract_features(test_images, 0.4)

# %%
X_feature_train = np.array(features_train)
X_feature_test = np.array(features_test)

# %%
# Modeli oluşturma
fft_model = Sequential()
fft_model.add(Dense(256, input_shape=X_feature_train[1].shape, activation='relu'))
fft_model.add(Dropout(0.5))
fft_model.add(Dense(128, activation='relu'))
fft_model.add(Dropout(0.5))
fft_model.add(Dense(64, activation='relu'))
fft_model.add(Dense(47, activation='softmax'))

opt=Adam(learning_rate=0.001)

fft_model.compile(optimizer=opt,loss='categorical_crossentropy',metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

fft_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_12 (Dense)            (None, 256)               16640
#
#  dropout_6 (Dropout)         (None, 256)               0
#
#  dense_13 (Dense)            (None, 128)               32896
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_14 (Dense)            (None, 64)                8256
#
#  dense_15 (Dense)            (None, 47)                3055
#
# ...
# Total params: 60847 (237.68 KB)
# Trainable params: 60847 (237.68 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history1 = fft_model.fit(X_feature_train, train_labels, epochs=100, batch_size=64 ,validation_data=(X_feature_test, test_labels), callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 1763/1763 [==============================] - 13s 6ms/step - loss: 3.8776 - accuracy: 0.0210 - val_loss: 3.8502 - val_accuracy: 0.0213
# Epoch 2/100
# 1763/1763 [==============================] - 11s 7ms/step - loss: 3.8506 - accuracy: 0.0201 - val_loss: 3.8502 - val_accuracy: 0.0213
# Epoch 3/100
# 1763/1763 [==============================] - 10s 6ms/step - loss: 3.8505 - accuracy: 0.0207 - val_loss: 3.8502 - val_accuracy: 0.0213
# Epoch 4/100
# 1524/1763 [========================>.....] - ETA: 1s - loss: 3.8505 - accuracy: 0.0198
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 history1 = fft_model.fit(X_feature_train, train_labels, epochs=100, batch_size=64 ,validation_data=(X_feature_test, test_labels), callbacks=[early_stopping])
#
# ...

# %%
#fcnn_loss, fcnn_accuracy = fcnn_model.evaluate(x_test_fft, y_test, verbose=0)

# %%
# Modeli oluşturma
model = Sequential()
model.add(Flatten(input_shape=(28, 28)))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dense(47, activation='softmax'))

opt=Adam(learning_rate=0.001)

model.compile(optimizer=opt,loss='categorical_crossentropy',metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Modeli oluşturma
# ----> 2 model = Sequential()
#       3 model.add(Flatten(input_shape=(28, 28)))
#       4 model.add(Dense(256, activation='relu'))
#
# NameError: name 'Sequential' is not defined

# %%
train_images = np.array(train_images)
test_images = np.array(test_images)

# %%
history2 = model.fit(train_images,train_labels, epochs=20, batch_size=64 ,validation_data=(test_images, test_labels), callbacks=[early_stopping])

# %%
cnn_model = Sequential()
cnn_model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(28, 28, 1)))
cnn_model.add(MaxPooling2D(pool_size=(2, 2)))
cnn_model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
cnn_model.add(MaxPooling2D(pool_size=(2, 2)))
cnn_model.add(Flatten())
cnn_model.add(Dense(256, activation='relu'))
cnn_model.add(Dropout(0.5))
cnn_model.add(Dense(128, activation='relu'))
cnn_model.add(Dropout(0.5))
cnn_model.add(Dense(64, activation='relu'))
cnn_model.add(Dense(47, activation='softmax'))

opt=Adam(learning_rate=0.001)

cnn_model.compile(optimizer=opt,loss='categorical_crossentropy',metrics=['accuracy'])

cnn_model.summary()

# %%
history3 = cnn_model.fit(train_images,train_labels, epochs=20, batch_size=64 ,validation_data=(test_images, test_labels))
